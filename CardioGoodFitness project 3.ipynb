# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew

# %%
df=pd.read_csv("CardioGoodFitness.csv")

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
#cheack is null values:-
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# there is no missing values in the dataset

# %%
#cheak for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# there is no duplicated values in the dataset

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
df.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
df["Product"].value_counts()
# Out:
# Product
# TM195    80
# TM498    60
# TM798    40
# Name: count, dtype: int64

# %%
df["Product"].value_counts(normalize=True)
# Out:
# Product
# TM195    0.444444
# TM498    0.333333
# TM798    0.222222
# Name: proportion, dtype: float64

# %%
ax=sns.countplot(data=df,x="Product")
for bars in ax.containers:
    ax.bar_label(bars)

# %%
#observation
#TM195 is the most product among the customers

# %%
df["Age"].value_counts()
# Out:
# Age
# 25    25
# 23    18
# 24    12
# 26    12
# 28     9
# 35     8
# 33     8
# 30     7
# 38     7
# 21     7
# 22     7
# 27     7
# 31     6
# 34     6
# 29     6
# 20     5
# 40     5
# 32     4
# 19     4
# 48     2
# 37     2
# 45     2
# 47     2
# 46     1
# 50     1
# 18     1
# 44     1
# 43     1
# 41     1
# 39     1
# 36     1
# 42     1
# Name: count, dtype: int64

# %%
df["Age"].value_counts(normalize=True)
# Out:
# Age
# 25    0.138889
# 23    0.100000
# 24    0.066667
# 26    0.066667
# 28    0.050000
# 35    0.044444
# 33    0.044444
# 30    0.038889
# 38    0.038889
# 21    0.038889
# 22    0.038889
# 27    0.038889
# 31    0.033333
# 34    0.033333
# 29    0.033333
# 20    0.027778
# 40    0.027778
# 32    0.022222
# 19    0.022222
# 48    0.011111
# 37    0.011111
# 45    0.011111
# 47    0.011111
# 46    0.005556
# 50    0.005556
# 18    0.005556
# 44    0.005556
# 43    0.005556
# 41    0.005556
# 39    0.005556
# 36    0.005556
# 42    0.005556
# Name: proportion, dtype: float64

# %%
ax=sns.histplot(data=df,x="Age")
for bars in ax.containers:
    ax.bar_label(bars)

# %%
#most of the customers are between in age 20 to 35

# %%
skew(df["Age"])
# Out:
# 0.9739571319710887

# %%
#its a positive value
#its a right skew

# %%
df.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      104
# Female     76
# Name: count, dtype: int64

# %%
ax=sns.countplot(data=df,x="Gender")
for bars in ax.containers:
    ax.bar_label(bars)

# %%
#most of the customers are male around  in 104

# %%
sns.histplot(data=df,x="Education")
# Out:
# <Axes: xlabel='Education', ylabel='Count'>

# %%
#we can use also use in countplot

# %%
ax=sns.countplot(data=df,x="Education")
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df["Education"].value_counts()
# Out:
# Education
# 16    85
# 14    55
# 18    23
# 15     5
# 13     5
# 12     3
# 21     3
# 20     1
# Name: count, dtype: int64

# %%
#85 of the customers are more like fresh graduates with 16 yrs of educations

# %%
df.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
df["MaritalStatus"].value_counts()
# Out:
# MaritalStatus
# Partnered    107
# Single        73
# Name: count, dtype: int64

# %%
ax=sns.countplot(data=df,x="MaritalStatus")
for bars in ax.containers:
    ax.bar_label(bars)

# %%
#almost 60% the customers are partnered

# %%
ax=sns.histplot(data=df,x="Usage")
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax=sns.countplot(data=df,x="Usage")
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df["Usage"].value_counts()
# Out:
# Usage
# 3    69
# 4    52
# 2    33
# 5    17
# 6     7
# 7     2
# Name: count, dtype: int64

# %%
#almost 70% customers are these product for either 3 or 4 days for week

# %%
df["Fitness"].value_counts()
# Out:
# Fitness
# 3    97
# 5    31
# 2    26
# 4    24
# 1     2
# Name: count, dtype: int64

# %%
ax=sns.countplot(data=df,x="Fitness")
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df["Income"].value_counts()
# Out:
# Income
# 45480    14
# 52302     9
# 46617     8
# 54576     8
# 53439     8
#          ..
# 65220     1
# 55713     1
# 68220     1
# 30699     1
# 95508     1
# Name: count, Length: 62, dtype: int64

# %%
plt.figure(figsize=(10,5))
ax=sns.histplot(data=df,x="Income")
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# most of the income earn between 30k to 60k

# %%
df["Miles"].value_counts()
# Out:
# Miles
# 85     27
# 95     12
# 66     10
# 75     10
# 47      9
# 106     9
# 94      8
# 113     8
# 53      7
# 100     7
# 180     6
# 200     6
# 56      6
# 64      6
# 127     5
# 160     5
# 42      4
# 150     4
# 38      3
# 74      3
# 170     3
# 120     3
# 103     3
# 132     2
# 141     2
# 280     1
# 260     1
# 300     1
# 240     1
# 112     1
# 212     1
# 80      1
# 140     1
# 21      1
# 169     1
# 188     1
# 360     1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(30,15))

sns.histplot(data=df,x="Miles")
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.xlabel("Miles", fontsize=25)
plt.ylabel("Count", fontsize=25)



plt.title("Histogram of Miles", fontsize=25)  # Increase title size
# Out:
# Text(0.5, 1.0, 'Histogram of Miles')

# %%
#distribution is right skewed beacause of value above 200 miles an the on the

# %%
df["Miles"].describe()
# Out:
# count    180.000000
# mean     103.194444
# std       51.863605
# min       21.000000
# 25%       66.000000
# 50%       94.000000
# 75%      114.750000
# max      360.000000
# Name: Miles, dtype: float64

# %% [markdown]
# # BIVARIATE ANALYSIS

# %% [markdown]
# Product VS Age

# %%
sns.histplot(data=df,x="Age",hue="Product")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(data=df,x="Age",hue="Product")
# Out:
# <Axes: xlabel='Age'>

# %%
sns.displot(data=df,x="Age",col="Product",palette="Set1")
# Out:
# C:\Users\Vaibhav\AppData\Local\Temp\ipykernel_11580\108424183.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(data=df,x="Age",col="Product",palette="Set1")
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
#Product VS Gender

# %%
sns.countplot(data=df,x="Gender",hue="Product")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
cross_tab=pd.crosstab(df["Gender"],df["Product"])

# %%
cross_tab
# Out:
# Product  TM195  TM498  TM798
# Gender
# Female      40     29      7
# Male        40     31     33

# %%
cross_tab.plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='Gender'>

# %%
df.groupby("Gender")["Product"].value_counts(normalize=True)
# Out:
# Gender  Product
# Female  TM195      0.526316
#         TM498      0.381579
#         TM798      0.092105
# Male    TM195      0.384615
#         TM798      0.317308
#         TM498      0.298077
# Name: proportion, dtype: float64

# %% [markdown]
# Product VS Educations

# %%
sns.histplot(data=df,x="Education",hue="Product")
# Out:
# <Axes: xlabel='Education', ylabel='Count'>

# %%
sns.countplot(data=df,x="Education",hue="Product")
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
cross_tab=pd.crosstab(df["Education"],df["Product"])

# %%
cross_tab
# Out:
# Product    TM195  TM498  TM798
# Education
# 12             2      1      0
# 13             3      2      0
# 14            30     23      2
# 15             4      1      0
# 16            39     31     15
# 18             2      2     19
# 20             0      0      1
# 21             0      0      3

# %%
cross_tab.plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='Education'>

# %%
#Observations
# -most of the customers 16 and 16+

# %%
df.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %% [markdown]
# Product VS MaritalStatus

# %%
sns.countplot(data=df,x="MaritalStatus",hue="Product")
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %%
df.groupby("Product")["MaritalStatus"].value_counts(normalize=True)
# Out:
# Product  MaritalStatus
# TM195    Partnered        0.600
#          Single           0.400
# TM498    Partnered        0.600
#          Single           0.400
# TM798    Partnered        0.575
#          Single           0.425
# Name: proportion, dtype: float64

# %%
cross_tab=pd.crosstab(df["Product"],df["MaritalStatus"])

# %%
cross_tab
# Out:
# MaritalStatus  Partnered  Single
# Product
# TM195                 48      32
# TM498                 36      24
# TM798                 23      17

# %%
#Observations 
# -the most product buyer is partnered in TM195

# %%
df.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %% [markdown]
# Product VS Usage

# %%
sns.histplot(data=df,x="Usage",hue="Product")
# Out:
# <Axes: xlabel='Usage', ylabel='Count'>

# %%
sns.boxplot(data=df,x="Product",y="Usage",hue="Gender")
# Out:
# <Axes: xlabel='Product', ylabel='Usage'>

# %%
print(df.dtypes)
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object
